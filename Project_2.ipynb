# %% [markdown]
# <a href="https://colab.research.google.com/github/jvwk/Project-2/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2
# ### *Jaco van Wyk*
# -----------

# %% [markdown]
# ## **First choice: Stroke Prediction Data Set**
#
# <br>
#
# **1. Source of data**
#
# >  https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset
#
# <br>
#
# **2. Brief description of data**
#
# >According to the World Health Organization (WHO) stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths.
# >
# >This dataset is used to predict whether a patient is likely to get stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.
#
# <br>
#
# **3. What is the target?**
#
# >*stroke*: 1 if the patient had a stroke or 0 if not
#
# <br>
#
# **4. What does one row represent? (A person? A business? An event? A product?)**
#
# >A person
#
# <br>
#
# **5. Is this a classification or regression problem?**
#
# >Classification
#
# <br>
#
# **6. How many features does the data have?**
#
# >The data contains 12 attributes
#
# <br>
#
# **7. How many rows are in the dataset?**
#
# >The data contains 5110 observations
#
# <br>
#
# **8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?**
#
# >There are missing values in the BMI feature

# %%
import pandas as pd
file = '/content/drive/MyDrive/CodingDojo/03-AdvancedML/Week09/Data/healthcare_dataset_stroke_data.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# ## **Second choice: Car Insurance Data Set**
#
# <br>
#
# **1. Source of data**
#
# >  https://www.kaggle.com/datasets/sagnik1511/car-insurance-data
#
# <br>
#
# **2. Brief description of data**
#
# >The company has shared its annual car insurance data, including characteristics of drivers and their vehicles, with claim outocome (ie whether the insured claimed or not)
#
# <br>
#
# **3. What is the target?**
#
# >*OUTCOME*: 1 if the insured made a claim or 0 if not
#
# <br>
#
# **4. What does one row represent? (A person? A business? An event? A product?)**
#
# >A person
#
# <br>
#
# **5. Is this a classification or regression problem?**
#
# >Classification
#
# <br>
#
# **6. How many features does the data have?**
#
# >The data contains 18 attributes
#
# <br>
#
# **7. How many rows are in the dataset?**
#
# >The data contains 10 000 observations
#
# <br>
#
# **8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?**
#
# >There are missing values in the credit score and annual mileage features

# %%
import pandas as pd
file = '/content/drive/MyDrive/CodingDojo/03-AdvancedML/Week09/Data/Car_Insurance_Claim.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape
# Out:
# (10000, 19)

# %%
df.isna().sum()
# Out:
# ID                       0
# AGE                      0
# GENDER                   0
# RACE                     0
# DRIVING_EXPERIENCE       0
# EDUCATION                0
# INCOME                   0
# CREDIT_SCORE           982
# VEHICLE_OWNERSHIP        0
# VEHICLE_YEAR             0
# MARRIED                  0
# CHILDREN                 0
# POSTAL_CODE              0
# ANNUAL_MILEAGE         957
# VEHICLE_TYPE             0
# SPEEDING_VIOLATIONS      0
# DUIS                     0
# PAST_ACCIDENTS           0
# OUTCOME                  0
# dtype: int64
